# %%
# !git clone https://github.com/ultralytics/yolov5.git # clone
# %cd yolov5
# %pip install -r requirements.txt # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.6/112.6 GB disk)

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-seg' for x in p5]  # segmentation models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Me3SXyIURnSFXRaTS79D")
project = rf.workspace("isrc-egg").project("egg-monitoring")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# RoboflowError                             Traceback (most recent call last)
# <ipython-input-6-ef9eee164c0d> in <cell line: 0>()
#       3 from roboflow import Roboflow
#       4 rf = Roboflow(api_key="Me3SXyIURnSFXRaTS79D")
# ----> 5 project = rf.workspace("isrc-egg").project("egg-monitoring")
#       6 version = project.version(3)
#       7 dataset = version.download("yolov5")
#
# /usr/local/lib/python3.11/dist-packages/roboflow/core/workspace.py in project(self, project_id)
#      92             raise RuntimeError(f"The {project_id} project is not available in this ({self.url}) workspace")
#      93
# ---> 94         dataset_info = rfapi.get_project(self.__api_key, self.url, project_id)
#      95         dataset_info = dataset_info["project"]
#      96
#
# ...

# %%
# %cd /content/yolov6
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-sexg' fox x in p5]  # segmentation models

for x in cls:
    attempt_download(f'weights/yolov6{x}.pt')
# Out:
#   File "<ipython-input-8-62bba13b4f00>", line 5
#     cls = [f'{x}-sexg' fox x in p5]  # segmentation models
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# !python segment/train.py --img 640 --batch 32 --epochs 20 --data "/content/Egg-Monitoring-4/data.yaml" --weights yolov5s-seg.pt
# Check if training completed successfully and the results.
# Out:
# python3: can't open file '/content/segment/train.py': [Errno 2] No such file or directory
