# %%
# !git clone https://github.com/ultralytics/yolov5.git # clone
# %cd yolov5
# %pip install -r requirements.txt # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.0/112.6 GB disk)

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-seg' for x in p5]  # segmentation models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# ...
# 100%|██████████| 4.11M/4.11M [00:00<00:00, 243MB/s]
#
# ...
# 100%|██████████| 14.9M/14.9M [00:00<00:00, 393MB/s]
#
# ...
# 100%|██████████| 42.4M/42.4M [00:00<00:00, 383MB/s]
#
# ...
# 100%|██████████| 91.9M/91.9M [00:00<00:00, 306MB/s]
#
# ...
# 100%|██████████| 170M/170M [00:00<00:00, 278MB/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="F2cDhcH9cDqwiJXbE2LM")
project = rf.workspace("egg-hd6q7").project("egg_monitoring")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Egg_Monitoring-1 in yolov5pytorch:: 100%|██████████| 1332/1332 [00:00<00:00, 8606.74it/s]

# %%
# %cd /content/yolov5
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-seg' for x in p5]  # segmentation models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# /content/yolov5

# %%
# !python segment/train.py --img 640 --batch 64 --epochs 100 --data "/content/yolov5/Egg_Monitoring-1/data.yaml" --weights yolov5m-seg.pt
# Check if training completed successfully and the results.
# Out:
# 2025-01-25 07:24:07.515512: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-25 07:24:07.535414: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-25 07:24:07.541526: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python segment/train.py --img 640 --batch 16 --epochs 50 --data "/content/yolov5/Egg_Monitoring-1/data.yaml" --weights "/content/yolov5/runs/train-seg/exp/weights/best.pt"
# Check if training completed successfully and the results.
# Out:
# 2025-01-24 16:32:31.064147: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 16:32:31.084795: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 16:32:31.090951: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python segment/train.py --img 640 --batch 16 --epochs 50 --data "/content/yolov5/Egg_Monitoring-1/data.yaml" --weights yolov5n-seg.pt
# Check if training completed successfully and the results.
# Out:
# 2025-01-24 16:55:29.278484: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 16:55:29.313532: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 16:55:29.323585: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python segment/train.py --img 640 --batch 16 --epochs 50 --data "/content/yolov5/Egg_Monitoring-1/data.yaml" --weights "/content/yolov5/runs/train-seg/exp3/weights/best.pt"
# Out:
# 2025-01-24 17:16:15.173113: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-24 17:16:15.193351: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-24 17:16:15.199558: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
